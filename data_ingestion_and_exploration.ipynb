# %%
import findspark
findspark.init()

# %%
from pyspark.sql import SparkSession, col, sum

spark = SparkSession.builder.appName("FinancialFraudDetection").getOrCreate()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/03/22 22:09:51 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
def alalysis(path: str):
    df = spark.read.csv(path, header=True, inferSchema=True)

    numerical_columns = [col for col, dtype in df.dtypes if dtype == "int" or dtype == "double"]

    df.select(numerical_columns).describe().show()

    categorical_columns = [col for col, dtype in df.dtypes if dtype == "string"]

    for col_name in categorical_columns:
        df.groupBy(col_name).count().show()

# %%
import os

files = os.listdir("../archive")

for file in files:
    alalysis(f"./archive/{file}")
    print("------------------------------------------------")
# Out:
# +-------+-------------------+-------------------+---------------------+-------------------------+----------------------------+------------------+--------------------+----------------------+-----------------+------------------+------------------+-----------------+--------------------+--------------------------------+-----------------+------------------+------------------+-------------------+------------------+-------------------+---------------------+-------------------+-------------------------+-------------------+-------------------------+------------------+------------------+
# ...
